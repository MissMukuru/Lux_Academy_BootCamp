# %% [markdown]
# LUX ACADEMY PROJECT 1 WEEK 1:
# Weather Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv(r"C:\Users\HPPC\Desktop\Data Science build up day\1. Weather Data.csv")
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.describe()

df.info()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# Q1

# %%
df.loc[df["Weather"] == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# Q2

# %%
df.loc[df['Wind Speed_km/h'] == 4].sum()
# Out:
# Date/Time           1/1/2012 0:001/1/2012 1:001/5/2012 0:001/5/201...
# Temp_C                                                         3328.6
# Dew Point Temp_C                                                954.1
# Rel Hum_%                                                       34523
# Wind Speed_km/h                                                  1896
# Visibility_km                                                 11974.7
# Press_kPa                                                    48081.93
# Weather             FogFogSnowSnowCloudyCloudyCloudySnowFogMostly ...
# dtype: object

# %%
df.loc[df['Wind Speed_km/h'] == 4].count()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %% [markdown]
# Q3

# %%
df.isnull()

df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# Q4

# %%
df.rename(columns= {'Weather' : 'Weather_Condition'})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# Q5

# %%
mean_visbility = df['Visibility_km'].mean()
mean_visbility
# Out:
# 27.664446721311478

# %% [markdown]
# Q6

# %%
Q6_data = df[(df['Wind Speed_km/h'] > 24 ) & (df['Visibility_km'] == 25)]

Q6_data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# Q7

# %%
Weather_data = pd.DataFrame(df)

# %%
numeric_colums = Weather_data.select_dtypes(include= 'number')

numeric_colums = pd.concat([df['Weather'], numeric_colums], axis = 1)

mean_weather_conditions = Weather_data.groupby('Weather').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
mean_weather_conditions = Weather_data.groupby('Weather').sum()
mean_weather_conditions
# Out:
#                                                                                  Date/Time  \
# Weather
# Clear                                    1/3/2012 19:001/5/2012 18:001/5/2012 19:001/5/...
# Cloudy                                   1/1/2012 17:001/1/2012 20:001/1/2012 21:001/1/...
# Drizzle                                  1/23/2012 21:002/17/2012 4:003/28/2012 17:003/...
# Drizzle,Fog                              1/23/2012 20:001/27/2012 11:001/27/2012 12:001...
# Drizzle,Ice Pellets,Fog                                                    12/17/2012 9:00
# Drizzle,Snow                                              12/17/2012 15:0012/19/2012 18:00
# Drizzle,Snow,Fog                         12/18/2012 21:0012/18/2012 22:0012/18/2012 23:...
# Fog                                      1/1/2012 0:001/1/2012 1:001/1/2012 4:001/1/201...
# Freezing Drizzle                         1/7/2012 11:001/7/2012 12:001/13/2012 10:001/1...
# ...

# %% [markdown]
# Q8

# %%
Q8_df = df[(df['Weather'] == 'clear') & ((df['Rel Hum_%'] > 50) | (df['Visibility_km'] > 40))]
Q8_df
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather]
# Index: []

# %% [markdown]
# Q9

# %%
snow_weather = df.loc[df['Weather']== 'Snow']

snow_weather.sum()

snow_weather_count = len(snow_weather)

snow_weather_count
# Out:
# 390
